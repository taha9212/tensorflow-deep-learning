# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
mnist = tf.keras.datasets.mnist

# %%
(tranies_img, tranies_label),(test_img, test_label) = mnist.load_data()

# %%
tranies_img = tranies_img / 255.0

# %%
test_img = test_img/ 255.0

# %%
model = tf.keras.models.Sequential([ tf.keras.layers.Flatten(),
                                     tf.keras.layers.Dense(512, activation = tf.nn.relu,),
                                     tf.keras.layers.Dense(10, activation = tf.nn.softmax)])

# %%
model.compile(optimizer = tf.keras.optimizers.RMSprop(),
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])

# %%
model.fit(tranies_img, tranies_label, epochs = 5, batch_size = 128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2576 - accuracy: 0.9263
# Epoch 2/5
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.1030 - accuracy: 0.9688
# Epoch 3/5
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.0686 - accuracy: 0.9798
# Epoch 4/5
# 60000/60000 [==============================] - 4s 61us/sample - loss: 0.0505 - accuracy: 0.9845
# Epoch 5/5
# 60000/60000 [==============================] - 4s 61us/sample - loss: 0.0373 - accuracy: 0.9887

# %%
model.evaluate(test_img, test_label)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.07587674697395413, 0.976]

# %%
tranies_img.shape
# Out:
# (60000, 28, 28)
